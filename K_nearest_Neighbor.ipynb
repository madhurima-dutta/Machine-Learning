# %% [markdown]
# <a href="https://colab.research.google.com/github/madhurima-dutta/Machine-Learning/blob/main/K_nearest_Neighbor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Predicting the category of tomato and carrot by KNN method

X=[[10,9],[1,4],[10,1],[7,10],[3,10],[1,1],[8,5],[3,7],[3,6],[7,3]] #sweetness and crunchiness
Z=['apple', 'bacon', 'banana', 'sweet potato', 'celery', 'cheese', 'grape', 'green bean', 'nuts', 'orange'] #name
Y=['fruit','protein','fruit','vegetable','vegetable','protein','fruit','vegetable','protein','fruit'] #category

# !pip install scikit-learn

from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=3)

classifier.fit (X,Y)

tomato = [[6,4]]
print (classifier.predict (tomato))

carrot = [[4,9]]
print (classifier.predict (carrot))
# Out:
# ...
# ['fruit']
# ['vegetable']

# %%
import pandas as pd

df=pd.DataFrame(X,columns=['Sweetness','Crunchiness'])
df['Name']= Z
df['Category']=Y
first_column=df.pop ('Name')
df.insert(0,'Name',first_column)
print()
display(df)
# Out:
#            Name  Sweetness  Crunchiness   Category
# 0         apple         10            9      fruit
# 1         bacon          1            4    protein
# 2        banana         10            1      fruit
# 3  sweet potato          7           10  vegetable
# 4        celery          3           10  vegetable
# 5        cheese          1            1    protein
# 6         grape          8            5      fruit
# 7    green bean          3            7  vegetable
# 8          nuts          3            6    protein
# 9        orange          7            3      fruit

# %%
import seaborn as sns

sns.scatterplot(data=df,x='Sweetness',y='Crunchiness',hue=Y)
# Out:
# <Axes: xlabel='Sweetness', ylabel='Crunchiness'>
